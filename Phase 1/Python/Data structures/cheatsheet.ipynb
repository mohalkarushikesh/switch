# %% [markdown]
# - **List**: Ordered, mutable, duplicates allowed.
# - **Dictionary**: Ordered, mutable, keys must be unique.
# - **Set**: Unordered, mutable collection of unique items; automatically removes duplicates.
# - **Tuple**: Ordered, immutable; cannot be modified, added to, or resized after creation. Indexed, Heterogeneous, Allows multiple duplicates
